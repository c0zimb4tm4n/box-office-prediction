# %%
import pandas as pd
import catboost as cb
from sklearn.model_selection import train_test_split, cross_val_score, KFold, GridSearchCV
from sklearn.metrics import mean_squared_error, r2_score
import joblib

# %%
df = pd.read_csv('../../data/cleaned/data_clean_v6.csv')

# %%
features = ['actor', 'actress', 'director', 'writer', 'Production_Company', 'runtimeMinutes', 'genres', 'isAdult']
target = 'averageRating'

# %%
X_train, X_test, y_train, y_test = train_test_split(df[features], df[target], test_size=0.3, random_state=42)
categorical_features_indices = [X_train.columns.get_loc(col) for col in ['actor', 'actress', 'director', 'Production_Company', 'writer', 'genres']]

# %%
model = cb.CatBoostRegressor(
    iterations=1500,
    learning_rate=0.1,
    depth=8,
    eval_metric='RMSE',
    l2_leaf_reg = 5,
    cat_features=categorical_features_indices,
    use_best_model=True
)

# %%
model.fit(X_train, y_train, eval_set=(X_test, y_test), early_stopping_rounds=50, verbose=100)
# Out:
# 0:	learn: 0.9148800	test: 0.9121256	best: 0.9121256 (0)	total: 844ms	remaining: 21m 4s
# 100:	learn: 0.5329261	test: 0.5122857	best: 0.5122857 (100)	total: 45.3s	remaining: 10m 28s
# 200:	learn: 0.4947259	test: 0.4727584	best: 0.4727584 (200)	total: 1m 36s	remaining: 10m 22s
# 300:	learn: 0.4651607	test: 0.4426011	best: 0.4426011 (300)	total: 2m 42s	remaining: 10m 46s
# 400:	learn: 0.4442971	test: 0.4209614	best: 0.4209614 (400)	total: 5m 2s	remaining: 13m 47s
# 500:	learn: 0.4245773	test: 0.4009492	best: 0.4009492 (500)	total: 5m 58s	remaining: 11m 53s
# 600:	learn: 0.4079913	test: 0.3839516	best: 0.3839516 (600)	total: 6m 47s	remaining: 10m 9s
# 700:	learn: 0.3935638	test: 0.3690219	best: 0.3690219 (700)	total: 7m 30s	remaining: 8m 33s
# 800:	learn: 0.3818138	test: 0.3568211	best: 0.3568211 (800)	total: 8m 17s	remaining: 7m 14s
# 900:	learn: 0.3716192	test: 0.3464861	best: 0.3464861 (900)	total: 9m 2s	remaining: 6m
# 1000:	learn: 0.3608386	test: 0.3354235	best: 0.3354235 (1000)	total: 9m 48s	remaining: 4m 53s
# 1100:	learn: 0.3518654	test: 0.3265653	best: 0.3265653 (1100)	total: 10m 30s	remaining: 3m 48s
# 1200:	learn: 0.3448875	test: 0.3197184	best: 0.3197184 (1200)	total: 11m 18s	remaining: 2m 48s
# 1300:	learn: 0.3381730	test: 0.3132727	best: 0.3132727 (1300)	total: 12m 37s	remaining: 1m 55s
# 1400:	learn: 0.3308127	test: 0.3061207	best: 0.3061207 (1400)	total: 13m 35s	remaining: 57.6s
# 1499:	learn: 0.3248600	test: 0.3003134	best: 0.3003134 (1499)	total: 14m 17s	remaining: 0us
#
# bestTest = 0.3003134091
# bestIteration = 1499

# %%
#run only once to get optimal params
param_grid = {
    'iterations': [1000, 1500, 2000],
    'depth': [6, 7, 8],
    'learning_rate': [0.01, 0.05, 0.1],
    'l2_leaf_reg': [1, 3, 5]  # Values for L2 regularization
}

# Perform grid search with cross-validation
grid_search = GridSearchCV(model, param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)
grid_search.fit(X_train, y_train, eval_set=(X_test, y_test), early_stopping_rounds=50, verbose=100)
print(grid_search.best_params_)
print(grid_search.cv_results_)

# %%
#run only once to check overfitting. If ran gridsearch, no need to evaluate seperately
scores = cross_val_score(model, X_train, y_train, cv=KFold(n_splits=5), scoring="neg_mean_squared_error", fit_params={'eval_set': [(X_test, y_test)]})
print(scores)

# %%
y_pred = model.predict(X_test)
rmse = mean_squared_error(y_test, y_pred, squared=False)
print(f'Root Mean Squared Error: {rmse}')
# Out:
# Root Mean Squared Error: 0.3003133990829797

# %%
r2_score(y_pred=y_pred, y_true=y_test)
# Out:
# 0.9010392577580292

# %%
hypothetical_movie = {
    'actor': 'Leonardo Dicaprio',
    'actress': 'Kate Winslet',
    'director': 'Christopher Nolan',
    'writer': 'Steven Spielberg',
    "Production_Company":"Twentieth Century Fox",
    'runtimeMinutes': 150,
    'genres': 'Thriller',
    'isAdult': 0
}

new_data = pd.DataFrame([hypothetical_movie])

predicted_rating = model.predict(new_data)
print(f'Predicted Rating: {predicted_rating[0]}')
# Out:
# Predicted Rating: 7.000901735878847

# %%
#get movies from dataset based on Production Company pattern. Only for testing TODO: remove later
import re
df[df['Production_Company'].apply(lambda x: bool(re.search('Fox', str(x))))]
# Out:
#            tconst       actor         actress            director  \
# 9       tt0118589  Eric Benét    Mariah Carey  Vondie Curtis-Hall
# 10      tt0118589  Eric Benét    Mariah Carey  Vondie Curtis-Hall
# 11      tt0118589  Eric Benét    Mariah Carey  Vondie Curtis-Hall
# 12      tt0118589  Eric Benét    Mariah Carey  Vondie Curtis-Hall
# 13      tt0118589  Eric Benét    Mariah Carey  Vondie Curtis-Hall
# ...           ...         ...             ...                 ...
# 285465  tt6628394    Jon Hamm   Cynthia Erivo        Drew Goddard
# 285466  tt6628394    Jon Hamm   Cynthia Erivo        Drew Goddard
# 285467  tt6628394    Jon Hamm  Dakota Johnson        Drew Goddard
# 285468  tt6628394    Jon Hamm  Dakota Johnson        Drew Goddard
# 285469  tt6628394    Jon Hamm  Dakota Johnson        Drew Goddard
#
#               producer          writer  averageRating  numVotes titleType  \
# 9        Laurence Mark  Cheryl L. West            2.4     24015     movie
# 10       Laurence Mark  Cheryl L. West            2.4     24015     movie
# 11       Laurence Mark  Cheryl L. West            2.4     24015     movie
# 12       Laurence Mark     Kate Lanier            2.4     24015     movie
# 13       Laurence Mark     Kate Lanier            2.4     24015     movie
# ...                ...             ...            ...       ...       ...
# 285465  Jeremy Latcham         missing            7.1    163092     movie
# 285466  Jeremy Latcham         missing            7.1    163092     movie
# 285467  Jeremy Latcham         missing            7.1    163092     movie
# 285468  Jeremy Latcham         missing            7.1    163092     movie
# 285469  Jeremy Latcham         missing            7.1    163092     movie
#
#                       primaryTitle  isAdult  startYear  runtimeMinutes  \
# 9                          Glitter        0       2001             104
# 10                         Glitter        0       2001             104
# 11                         Glitter        0       2001             104
# 12                         Glitter        0       2001             104
# 13                         Glitter        0       2001             104
# ...                            ...      ...        ...             ...
# 285465  Bad Times at the El Royale        0       2018             141
# 285466  Bad Times at the El Royale        0       2018             141
# 285467  Bad Times at the El Royale        0       2018             141
# 285468  Bad Times at the El Royale        0       2018             141
# 285469  Bad Times at the El Royale        0       2018             141
#
#          genres  inflation_corrector  Revenue_InflationCorrected  \
# 9         Drama             1.720508                     9069944
# 10        Music             1.720508                     9069944
# 11      Romance             1.720508                     9069944
# 12        Drama             1.720508                     9069944
# 13        Music             1.720508                     9069944
# ...         ...                  ...                         ...
# 285465    Drama             1.213435                    38687610
# 285466  Mystery             1.213435                    38687610
# 285467    Crime             1.213435                    38687610
# 285468    Drama             1.213435                    38687610
# 285469  Mystery             1.213435                    38687610
#
#            Production_Company
# 9       Twentieth Century Fox
# 10      Twentieth Century Fox
# 11      Twentieth Century Fox
# 12      Twentieth Century Fox
# 13      Twentieth Century Fox
# ...                       ...
# 285465  Twentieth Century Fox
# 285466  Twentieth Century Fox
# 285467  Twentieth Century Fox
# 285468  Twentieth Century Fox
# 285469  Twentieth Century Fox
#
# [22769 rows x 17 columns]

# %%
joblib.dump(model, 'ratingModelv1.joblib')
# Out:
# ['ratingModelv1.joblib']
